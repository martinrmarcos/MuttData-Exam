# %%
## import some various libraries
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import re
import json
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

import unidecode

import urllib.request

import warnings
warnings.filterwarnings("ignore")
import argparse
import logging
import time
from sqlalchemy import create_engine

import holidays

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
### SQL data:
username = 'postgres'
password = 'Mutt2023'
host = '0.0.0.0'  
port = '5432'  
database_name = 'MuttDB'
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database_name}')
connection = engine.connect()

# %%
### Testing of the different functionalities of the app

# %%
### testing the downlaod of any coin without arguments, retrieves todays iinformation

# !python GetCoinInfoForDay.py 'bitcoin'
# Out:
# 2023-09-08 20:45:58,550 - user entered 08-09-2023 as a date
# 2023-09-08 20:45:58,550 - user entered 08-09-2023 as a to_date
# 2023-09-08 20:45:58,551 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:00,666 - information has been loaded to a DataFrame for bitcoin for the date: 08-09-2023
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-09-2023_to_08-09-2023.csv
# Great Success!!!

# %%
### testing the downlaod of any coin with one date, should only download that dates information

# !python GetCoinInfoForDay.py 'bitcoin' '2023-08-08'
# Out:
# 2023-09-08 20:46:02,600 - user entered 08-08-2023 as a date
# 2023-09-08 20:46:02,600 - user entered 08-08-2023 as a to_date
# 2023-09-08 20:46:02,600 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:04,727 - information has been loaded to a DataFrame for bitcoin for the date: 08-08-2023
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-08-2023_to_08-08-2023.csv
# Great Success!!!

# %%
### testing the downlaod of any coin with wrong format on the date, should get an error for it

# !python GetCoinInfoForDay.py 'bitcoin' '2023-20-08'
# Out:
# wrong date structure entered

# %%
### testing the downlaod of any coin with two dates, should bulk download the info between dates

# !python GetCoinInfoForDay.py 'bitcoin' '2022-08-08' '2022-08-12'
# Out:
# 2023-09-08 20:46:08,330 - user entered 08-08-2022 as a date
# 2023-09-08 20:46:08,330 - user entered 12-08-2022 as a to_date
# 2023-09-08 20:46:08,330 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:10,450 - information has been loaded to a DataFrame for bitcoin for the date: 08-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:12,549 - information has been loaded to a DataFrame for bitcoin for the date: 09-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:14,643 - information has been loaded to a DataFrame for bitcoin for the date: 10-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:16,747 - information has been loaded to a DataFrame for bitcoin for the date: 11-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:18,845 - information has been loaded to a DataFrame for bitcoin for the date: 12-08-2022
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-08-2022_to_12-08-2022.csv
# Great Success!!!

# %%
### testing the downlaod of any coin with two dates but not in the correct order, 
### should download an emtpy document as there are no dates selected

# !python GetCoinInfoForDay.py 'bitcoin' '2022-08-08' '2022-08-02'
# Out:
# 2023-09-08 20:46:20,625 - user entered 08-08-2022 as a date
# 2023-09-08 20:46:20,626 - user entered 02-08-2022 as a to_date
# 2023-09-08 20:46:20,626 - user entered bitcoin as selected coin
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-08-2022_to_02-08-2022.csv
# Great Success!!!

# %%
### testing the downlaod of any coin with two dates far appart, should bulk download the info between 
### dates and in case there a limit on the connection, should inform accordingly to know what to reprocess

# !python GetCoinInfoForDay.py 'bitcoin' '2022-08-08' '2022-09-12'
# Out:
# 2023-09-08 20:46:22,541 - user entered 08-08-2022 as a date
# 2023-09-08 20:46:22,541 - user entered 12-09-2022 as a to_date
# 2023-09-08 20:46:22,541 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:24,857 - information has been loaded to a DataFrame for bitcoin for the date: 08-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:26,957 - information has been loaded to a DataFrame for bitcoin for the date: 09-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:29,057 - information has been loaded to a DataFrame for bitcoin for the date: 10-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:31,160 - information has been loaded to a DataFrame for bitcoin for the date: 11-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:33,265 - information has been loaded to a DataFrame for bitcoin for the date: 12-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:35,363 - information has been loaded to a DataFrame for bitcoin for the date: 13-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:37,459 - information has been loaded to a DataFrame for bitcoin for the date: 14-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:39,565 - information has been loaded to a DataFrame for bitcoin for the date: 15-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:46:41,907 - information has been loaded to a DataFrame for bitcoin for the date: 16-08-2022
# 17-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 18-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 19-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 20-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 21-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 22-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 23-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 24-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 25-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 26-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 27-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 28-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 29-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 30-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 31-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 01-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 02-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 03-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 04-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 05-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 06-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 07-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 08-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 09-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 10-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 11-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 12-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-08-2022_to_12-09-2022.csv
# Great Success!!!

# %%
### testing the downlaod of any coin with two dates and an extra argument as a Y, should 
### bulk download the info between dates and also save it into postgreSQL

# !python GetCoinInfoForDay.py 'bitcoin' '2017-08-28' '2017-09-02' y
# Out:
# 2023-09-08 20:47:41,117 - user entered 28-08-2017 as a date
# 2023-09-08 20:47:41,118 - user entered 02-09-2017 as a to_date
# 2023-09-08 20:47:41,118 - user entered bitcoin as selected coin
# 28-08-2017 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:47:45,297 - information has been loaded to a DataFrame for bitcoin for the date: 29-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:47:47,398 - information has been loaded to a DataFrame for bitcoin for the date: 30-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:47:49,497 - information has been loaded to a DataFrame for bitcoin for the date: 31-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:47:51,792 - information has been loaded to a DataFrame for bitcoin for the date: 01-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:47:53,896 - information has been loaded to a DataFrame for bitcoin for the date: 02-09-2017
# 2023-09-08 20:47:53,897 - Opening SQL connection
# Connected to MuttDB database at 0.0.0.0:5432
# 2023-09-08 20:47:53,960 - Running: "SELECT * FROM coin_price_usd over the DB
# 2023-09-08 20:47:54,198 - Adding table nr 1 to the DB
# 2023-09-08 20:47:54,204 - Running: "SELECT * FROM maxmin_monthly_usd over the DB
# 2023-09-08 20:47:54,253 - Adding table nr 2 to the DB
# 2023-09-08 20:47:54,253 - Clossing SQL connection
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_28-08-2017_to_02-09-2017.csv
# Great Success!!!

# %%
sql_query = "select * from public.coin_price_usd where date between '2017-08-27T00:00:00' and '2017-09-06T00:00:00'"
dfsql = pd.read_sql_query(sql_query, engine)
dfsql
# Out:
#         date  coin_id                                          json_data  \
# 0 2017-08-28  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 1 2017-08-29  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 2 2017-08-30  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 3 2017-08-31  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 4 2017-09-01  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 5 2017-09-02  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 6 2017-09-03  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 7 2017-09-04  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 8 2017-09-05  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
#
#    current_price.usd  json
# 0        4216.242773  None
# 1        4394.063436  None
# 2        4553.806527  None
# 3        4702.938163  None
# 4        4863.193049  None
# 5        4556.597777  None
# 6        4632.462331  None
# 7        4317.185188  None
# 8        4447.875592  None

# %%
sql_query = "select * from public.maxmin_monthly_usd where year = '2017' and (month = 09 or month = 08)"
dfsql = pd.read_sql_query(sql_query, engine)
dfsql
# Out:
#    year  month  coin_id    max_price    min_price
# 0  2017      8  bitcoin  4702.938163  4216.242773
# 1  2017      9  bitcoin  4863.193049  4317.185188

# %%
### testing the downlaod of any coin with two dates and an extra argument as a Y and some 
### dates are the same as previous download, should bulk download the info between 
### dates and also save it into postgreSQL but considering the old data

# !python GetCoinInfoForDay.py 'bitcoin' '2017-08-30' '2017-09-05' y
# Out:
# 2023-09-08 20:47:56,132 - user entered 30-08-2017 as a date
# 2023-09-08 20:47:56,132 - user entered 05-09-2017 as a to_date
# 2023-09-08 20:47:56,132 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:47:58,249 - information has been loaded to a DataFrame for bitcoin for the date: 30-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:00,344 - information has been loaded to a DataFrame for bitcoin for the date: 31-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:02,444 - information has been loaded to a DataFrame for bitcoin for the date: 01-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:04,548 - information has been loaded to a DataFrame for bitcoin for the date: 02-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:06,660 - information has been loaded to a DataFrame for bitcoin for the date: 03-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:08,765 - information has been loaded to a DataFrame for bitcoin for the date: 04-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:10,868 - information has been loaded to a DataFrame for bitcoin for the date: 05-09-2017
# 2023-09-08 20:48:10,868 - Opening SQL connection
# Connected to MuttDB database at 0.0.0.0:5432
# 2023-09-08 20:48:10,928 - Running: "SELECT * FROM coin_price_usd over the DB
# 2023-09-08 20:48:11,168 - Adding table nr 1 to the DB
# 2023-09-08 20:48:11,174 - Running: "SELECT * FROM maxmin_monthly_usd over the DB
# 2023-09-08 20:48:11,222 - Adding table nr 2 to the DB
# 2023-09-08 20:48:11,222 - Clossing SQL connection
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_30-08-2017_to_05-09-2017.csv
# Great Success!!!

# %%
sql_query = "select * from public.coin_price_usd where date between '2017-08-27T00:00:00' and '2017-09-06T00:00:00'"
dfsql = pd.read_sql_query(sql_query, engine)
dfsql
# Out:
#         date  coin_id                                          json_data  \
# 0 2017-08-28  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 1 2017-08-29  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 2 2017-08-30  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 3 2017-08-31  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 4 2017-09-01  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 5 2017-09-02  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 6 2017-09-03  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 7 2017-09-04  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
# 8 2017-09-05  bitcoin  {"id": "bitcoin", "symbol": "btc", "name": "Bi...
#
#    current_price.usd  json
# 0        4216.242773  None
# 1        4394.063436  None
# 2        4553.806527  None
# 3        4702.938163  None
# 4        4863.193049  None
# 5        4556.597777  None
# 6        4632.462331  None
# 7        4317.185188  None
# 8        4447.875592  None

# %%
sql_query = "select * from public.maxmin_monthly_usd where year = '2017' and (month = 09 or month = 08)"
dfsql = pd.read_sql_query(sql_query, engine)
dfsql
# Out:
#    year  month  coin_id    max_price    min_price
# 0  2017      8  bitcoin  4702.938163  4216.242773
# 1  2017      9  bitcoin  4863.193049  4317.185188

# %%
try:
    # !python GetCoinInfoForDay.py 'bitcoin'
    # !python GetCoinInfoForDay.py 'bitcoin' '2023-08-08' 
    # !python GetCoinInfoForDay.py 'bitcoin' '2023-20-08' 
    # !python GetCoinInfoForDay.py 'bitcoin' '2022-08-08' '2022-08-12'
    # !python GetCoinInfoForDay.py 'bitcoin' '2022-08-08' '2022-08-02' 
    # !python GetCoinInfoForDay.py 'bitcoin' '2022-08-08' '2022-09-12' 
    # !python GetCoinInfoForDay.py 'bitcoin' '2017-08-28' '2017-09-02' y
    # !python GetCoinInfoForDay.py 'bitcoin' '2017-08-30' '2017-09-05' y
    print('All basic functionality is working accordingly')
except:
    print('There was a problem with the app')
# Out:
# 2023-09-08 20:48:13,008 - user entered 08-09-2023 as a date
# 2023-09-08 20:48:13,008 - user entered 08-09-2023 as a to_date
# 2023-09-08 20:48:13,008 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:15,237 - information has been loaded to a DataFrame for bitcoin for the date: 08-09-2023
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-09-2023_to_08-09-2023.csv
# Great Success!!!
# 2023-09-08 20:48:17,011 - user entered 08-08-2023 as a date
# 2023-09-08 20:48:17,012 - user entered 08-08-2023 as a to_date
# 2023-09-08 20:48:17,012 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:19,135 - information has been loaded to a DataFrame for bitcoin for the date: 08-08-2023
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-08-2023_to_08-08-2023.csv
# Great Success!!!
# wrong date structure entered
# 2023-09-08 20:48:22,686 - user entered 08-08-2022 as a date
# 2023-09-08 20:48:22,686 - user entered 12-08-2022 as a to_date
# 2023-09-08 20:48:22,686 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:24,802 - information has been loaded to a DataFrame for bitcoin for the date: 08-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:26,898 - information has been loaded to a DataFrame for bitcoin for the date: 09-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:28,992 - information has been loaded to a DataFrame for bitcoin for the date: 10-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:31,092 - information has been loaded to a DataFrame for bitcoin for the date: 11-08-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:33,194 - information has been loaded to a DataFrame for bitcoin for the date: 12-08-2022
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-08-2022_to_12-08-2022.csv
# Great Success!!!
# 2023-09-08 20:48:35,093 - user entered 08-08-2022 as a date
# 2023-09-08 20:48:35,093 - user entered 02-08-2022 as a to_date
# 2023-09-08 20:48:35,093 - user entered bitcoin as selected coin
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-08-2022_to_02-08-2022.csv
# Great Success!!!
# 2023-09-08 20:48:36,920 - user entered 08-08-2022 as a date
# 2023-09-08 20:48:36,920 - user entered 12-09-2022 as a to_date
# 2023-09-08 20:48:36,920 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:48:39,184 - information has been loaded to a DataFrame for bitcoin for the date: 08-08-2022
# 09-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 10-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 11-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 12-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 13-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 14-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 15-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 16-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 17-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 18-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 19-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 20-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 21-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 22-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 23-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 24-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 25-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 26-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 27-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 28-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 29-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 30-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 31-08-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 01-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 02-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 03-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 04-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 05-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# 06-09-2022 for bitcoin could not be loaded due to the APIs traffic restrictions
# Waiting for 2 seconds to be able to handle traffic
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:49:42,975 - information has been loaded to a DataFrame for bitcoin for the date: 07-09-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:49:45,335 - information has been loaded to a DataFrame for bitcoin for the date: 08-09-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:49:47,633 - information has been loaded to a DataFrame for bitcoin for the date: 09-09-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:49:50,076 - information has been loaded to a DataFrame for bitcoin for the date: 10-09-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:49:52,614 - information has been loaded to a DataFrame for bitcoin for the date: 11-09-2022
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:49:54,960 - information has been loaded to a DataFrame for bitcoin for the date: 12-09-2022
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_08-08-2022_to_12-09-2022.csv
# Great Success!!!
# 2023-09-08 20:49:57,082 - user entered 28-08-2017 as a date
# 2023-09-08 20:49:57,083 - user entered 02-09-2017 as a to_date
# 2023-09-08 20:49:57,083 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:49:59,194 - information has been loaded to a DataFrame for bitcoin for the date: 28-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:01,294 - information has been loaded to a DataFrame for bitcoin for the date: 29-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:03,389 - information has been loaded to a DataFrame for bitcoin for the date: 30-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:05,483 - information has been loaded to a DataFrame for bitcoin for the date: 31-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:07,593 - information has been loaded to a DataFrame for bitcoin for the date: 01-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:09,855 - information has been loaded to a DataFrame for bitcoin for the date: 02-09-2017
# 2023-09-08 20:50:09,856 - Opening SQL connection
# Connected to MuttDB database at 0.0.0.0:5432
# 2023-09-08 20:50:09,900 - Running: "SELECT * FROM coin_price_usd over the DB
# 2023-09-08 20:50:10,147 - Adding table nr 1 to the DB
# 2023-09-08 20:50:10,155 - Running: "SELECT * FROM maxmin_monthly_usd over the DB
# 2023-09-08 20:50:10,209 - Adding table nr 2 to the DB
# 2023-09-08 20:50:10,209 - Clossing SQL connection
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_28-08-2017_to_02-09-2017.csv
# Great Success!!!
# 2023-09-08 20:50:12,240 - user entered 30-08-2017 as a date
# 2023-09-08 20:50:12,240 - user entered 05-09-2017 as a to_date
# 2023-09-08 20:50:12,240 - user entered bitcoin as selected coin
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:14,357 - information has been loaded to a DataFrame for bitcoin for the date: 30-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:16,468 - information has been loaded to a DataFrame for bitcoin for the date: 31-08-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:18,570 - information has been loaded to a DataFrame for bitcoin for the date: 01-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:20,682 - information has been loaded to a DataFrame for bitcoin for the date: 02-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:22,789 - information has been loaded to a DataFrame for bitcoin for the date: 03-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:24,894 - information has been loaded to a DataFrame for bitcoin for the date: 04-09-2017
# Waiting for 2 seconds to be able to handle traffic
# 2023-09-08 20:50:27,003 - information has been loaded to a DataFrame for bitcoin for the date: 05-09-2017
# 2023-09-08 20:50:27,004 - Opening SQL connection
# Connected to MuttDB database at 0.0.0.0:5432
# 2023-09-08 20:50:27,073 - Running: "SELECT * FROM coin_price_usd over the DB
# 2023-09-08 20:50:27,357 - Adding table nr 1 to the DB
# 2023-09-08 20:50:27,365 - Running: "SELECT * FROM maxmin_monthly_usd over the DB
# 2023-09-08 20:50:27,435 - Adding table nr 2 to the DB
# 2023-09-08 20:50:27,435 - Clossing SQL connection
# DF was saved at: /Users/martinmarcos/ML Martin Marcos/Mutt Data Exam/GetCoinInfoForDay_Results/GetCoinInfoForDay_bitcoin_30-08-2017_to_05-09-2017.csv
# Great Success!!!
# All basic functionality is working accordingly

# %%
connection.close()
