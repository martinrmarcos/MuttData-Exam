# %%
# !python GetCoinInfoForDay.py 'bitcoin' '2023-08-08' '2023-09-07' y
# Out:
# 2023-09-08 18:24:54,825 - user entered 08-08-2023 as a date
# 2023-09-08 18:24:54,825 - user entered 07-09-2023 as a to_date
# 2023-09-08 18:24:54,825 - user entered bitcoin as selected coin
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:25:05,157 - information has been loaded to a DataFrame for bitcoin for the date: 08-08-2023
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:25:15,442 - information has been loaded to a DataFrame for bitcoin for the date: 09-08-2023
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:25:26,212 - information has been loaded to a DataFrame for bitcoin for the date: 10-08-2023
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:25:36,500 - information has been loaded to a DataFrame for bitcoin for the date: 11-08-2023
# Waiting for 10 seconds to be able to handle traffic
# ...

# %%
# !python GetCoinInfoForDay.py 'ethereum' '2023-08-08' '2023-09-07' y
# Out:
# 2023-09-08 18:30:19,082 - user entered 08-08-2023 as a date
# 2023-09-08 18:30:19,082 - user entered 07-09-2023 as a to_date
# 2023-09-08 18:30:19,082 - user entered ethereum as selected coin
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:30:29,402 - information has been loaded to a DataFrame for ethereum for the date: 08-08-2023
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:30:39,788 - information has been loaded to a DataFrame for ethereum for the date: 09-08-2023
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:30:50,088 - information has been loaded to a DataFrame for ethereum for the date: 10-08-2023
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:31:00,181 - information has been loaded to a DataFrame for ethereum for the date: 11-08-2023
# Waiting for 10 seconds to be able to handle traffic
# ...

# %%
# !python GetCoinInfoForDay.py 'cardano' '2023-08-08' '2023-09-07' y
# Out:
# 2023-09-08 18:35:41,625 - user entered 08-08-2023 as a date
# 2023-09-08 18:35:41,625 - user entered 07-09-2023 as a to_date
# 2023-09-08 18:35:41,625 - user entered cardano as selected coin
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:35:51,953 - information has been loaded to a DataFrame for cardano for the date: 08-08-2023
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:36:02,256 - information has been loaded to a DataFrame for cardano for the date: 09-08-2023
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:36:13,169 - information has been loaded to a DataFrame for cardano for the date: 10-08-2023
# Waiting for 10 seconds to be able to handle traffic
# 2023-09-08 18:36:23,469 - information has been loaded to a DataFrame for cardano for the date: 11-08-2023
# Waiting for 10 seconds to be able to handle traffic
# ...
